# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanHernandez26/Trabajo-Analisis-de-Datos/blob/main/Py_6_DiegoIvanHernandezBlanco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
harvard_reviews = pd.read_csv('JuevesLab/harvard_reviews.csv')

# %%
harvard_reviews.shape
# Out:
# (3184, 7)

# %%
harvard_reviews = pd.read_csv('JuevesLab/harvard_reviews.csv', index_col=0)
pd.set_option('display.max_columns', 5)
harvard_reviews
# Out:
#                           published_platform  rating  ...  \
# published_date                                        ...
# 2023-12-28T08:02:14-05:00             Mobile       5  ...
# 2023-12-12T00:38:26-05:00            Desktop       4  ...
# 2023-12-10T08:21:35-05:00             Mobile       3  ...
# 2023-11-07T21:20:21-05:00            Desktop       4  ...
# 2023-10-02T17:40:42-04:00            Desktop       5  ...
# ...                                      ...     ...  ...
# 2010-10-29T05:47:57-04:00            Desktop       3  ...
# 2010-08-23T06:08:51-04:00            Desktop       3  ...
# 2010-08-23T00:06:41-04:00            Desktop       5  ...
# 2010-06-03T07:37:36-04:00            Desktop       5  ...
# 2009-09-27T16:39:18-04:00            Desktop       5  ...
#
#                                                                        title  \
# published_date
# 2023-12-28T08:02:14-05:00                 Best classes and good environment
# ...

# %% [markdown]
# **CUENTO**
#
# Diego viajó con sus amigos a Boston sin mucho plan, solo sabían que querían conocer Harvard. Llegaron en metro, compraron café y se perdieron entre los edificios antiguos del campus. Uno de ellos intentó dar una “visita guiada improvisada”, leyendo carteles y bromeando sobre ser futuros genios. Cuando encontraron la estatua de John Harvard, todos tocaron su zapato para la buena suerte.
