# %% [markdown]
# # Evaluación. Tema 1.
# Analítica de Datos

# %% [markdown]
# Nombre de los integrantes del equipo

# %%
Muñiz Hernandez Alexis, garcia Lopez Brayan Alessandro, Hernandez Blanco DIego Ivan

# %% [markdown]
# ## Introducción
#
# En estos ejercicios vamos a trabajar con el dataset alojado en la ruta: **/
# datasets/harvard_reviews.csv**
#
# Ejecuta la siguiente celda para el dataframe con el contenido del dataset.

# %%
harvard_reviews = pd.read_csv("/content/Datasets/harvard_reviews (1).csv", index_col=0)
harvard_reviews
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review              0
# 2023-12-12T00:38:26-05:00            Desktop       4  review              0
# 2023-12-10T08:21:35-05:00             Mobile       3  review              0
# 2023-11-07T21:20:21-05:00            Desktop       4  review              0
# 2023-10-02T17:40:42-04:00            Desktop       5  review              0
# ...                                      ...     ...     ...            ...
# 2010-10-29T05:47:57-04:00            Desktop       3  review              0
# 2010-08-23T06:08:51-04:00            Desktop       3  review              0
# 2010-08-23T00:06:41-04:00            Desktop       5  review              0
# 2010-06-03T07:37:36-04:00            Desktop       5  review              2
# 2009-09-27T16:39:18-04:00            Desktop       5  review              1
#
#                                                                        title  \
# published_date
# 2023-12-28T08:02:14-05:00                 Best classes and good environment
# 2023-12-12T00:38:26-05:00                                 Harvard University
# 2023-12-10T08:21:35-05:00                                 Walk around campus
# 2023-11-07T21:20:21-05:00                     Interesting Harvard University
# 2023-10-02T17:40:42-04:00  Lovely university campus has many historic and...
# ...                                                                      ...
# 2010-10-29T05:47:57-04:00               amerikanischer campus fuer touristen
# 2010-08-23T06:08:51-04:00                               Weniger als erwartet
# 2010-08-23T00:06:41-04:00                              bellissima università
# 2010-06-03T07:37:36-04:00  Tolle Universität, definitiv einen Abstecher wert
# 2009-09-27T16:39:18-04:00                                            一度は行くべき
#
#                                                                         text
# published_date
# 2023-12-28T08:02:14-05:00  Good thanks for everything good work group 👍 h...
# 2023-12-12T00:38:26-05:00  Harvard University was founded in 1636 and is ...
# 2023-12-10T08:21:35-05:00  We did a walk around most of the Harvard Campu...
# 2023-11-07T21:20:21-05:00  We had a walk through the university grounds w...
# 2023-10-02T17:40:42-04:00  Finally made it to Harvard!!  This iconic univ...
# ...                                                                      ...
# 2010-10-29T05:47:57-04:00  wenn man in boston ist hat manmeistens zeit au...
# 2010-08-23T06:08:51-04:00  Von der Führung der Harvard University erhofft...
# 2010-08-23T00:06:41-04:00  da vedere questa città, studio sede di una del...
# 2010-06-03T07:37:36-04:00  Hallo,\nich habe ein Jahr an der Harvard Law S...
# 2009-09-27T16:39:18-04:00  とても歴史のある素敵な建物です。ハーバードスクエアーの駅の近くから無料のツアー（英語）をハー...
#
# [3184 rows x 6 columns]

# %% [markdown]
# ## Ejercicio 1
#
# Selecciona la columna ``text`` del dataframe reviews y asignalo a una variable llamada ``col_texto``

# %%
col_texto = harvard_reviews['text']
col_texto
# Out:
# published_date
# 2023-12-28T08:02:14-05:00    Good thanks for everything good work group 👍 h...
# 2023-12-12T00:38:26-05:00    Harvard University was founded in 1636 and is ...
# 2023-12-10T08:21:35-05:00    We did a walk around most of the Harvard Campu...
# 2023-11-07T21:20:21-05:00    We had a walk through the university grounds w...
# 2023-10-02T17:40:42-04:00    Finally made it to Harvard!!  This iconic univ...
#                                                    ...
# 2010-10-29T05:47:57-04:00    wenn man in boston ist hat manmeistens zeit au...
# 2010-08-23T06:08:51-04:00    Von der Führung der Harvard University erhofft...
# 2010-08-23T00:06:41-04:00    da vedere questa città, studio sede di una del...
# 2010-06-03T07:37:36-04:00    Hallo,\nich habe ein Jahr an der Harvard Law S...
# 2009-09-27T16:39:18-04:00    とても歴史のある素敵な建物です。ハーバードスクエアーの駅の近くから無料のツアー（英語）をハー...
# Name: text, Length: 3184, dtype: object

# %% [markdown]
# Pregunta complementaria: ¿qué tipo de objeto es **col_texto**? Si no estás seguro, puedes comprobarlo llamando a la función type de Python: type(desc).

# %% [markdown]
#  **¿qué tipo de objeto es col_texto?** = Es una Serie

# %% [markdown]
# ## Ejercicio 2
#
# Selecciona el primer valor de la columna `text` de reviews, asignándolo a la variable `primer_texto`.

# %%
primer_texto = harvard_reviews.text.iloc[0]
primer_texto
# Out:
# 'Good thanks for everything good work group 👍 harverd good college for everything development science etc thanks for support '

# %% [markdown]
# ## Ejercicio 3
#
# Selecciona la primera fila de datos (el primer registro) de `reviews`, asignándola a la variable `primera_fila`.

# %%
primera_fila = harvard_reviews.iloc[0]
primera_fila
# Out:
# published_platform                                               Mobile
# rating                                                                5
# type                                                             review
# helpful_votes                                                         0
# title                                Best classes and good environment
# text                  Good thanks for everything good work group 👍 h...
# Name: 2023-12-28T08:02:14-05:00, dtype: object

# %% [markdown]
# ## Ejercicio 4
#
# Selecciona los 10 primeros valores de la columna `title` en `reviews`, asignando el resultado a la variable `primeros_titulos`.
#
# Sugerencia: formatea su salida como una Serie pandas.

# %%
primeros_titulos = harvard_reviews.title.iloc[:10]
primeros_titulos
# Out:
# published_date
# 2023-12-28T08:02:14-05:00                   Best classes and good environment
# 2023-12-12T00:38:26-05:00                                   Harvard University
# 2023-12-10T08:21:35-05:00                                   Walk around campus
# 2023-11-07T21:20:21-05:00                       Interesting Harvard University
# 2023-10-02T17:40:42-04:00    Lovely university campus has many historic and...
# 2023-09-29T08:44:17-04:00       Interesting walk around campus grounds & river
# 2023-09-26T04:56:29-04:00                                  Inspirational place
# 2023-08-02T16:10:20-04:00               Harvard University student guided tour
# 2023-07-02T11:55:51-04:00                            Beautiful historic campus
# 2023-06-24T05:21:02-04:00                                          Nice campus
# Name: title, dtype: object

# %% [markdown]
# ## Ejercicio 5
#
# Selecciona los registros con etiquetas de índice `1`, `2`, `3`, `5` y `8`, asignando el resultado a la variable `reviews_filtradas`.
#
# En otras palabras, genere el siguiente DataFrame:
#
# <img src="https://github.com/joseisaiasmartinezcorona/AnaliticaLab/blob/master/imgs/ej-05.PNG?raw=1">

# %%
harvard_reviews.iloc[[1,2,3,5,8]]
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2023-12-12T00:38:26-05:00            Desktop       4  review              0
# 2023-12-10T08:21:35-05:00             Mobile       3  review              0
# 2023-11-07T21:20:21-05:00            Desktop       4  review              0
# 2023-09-29T08:44:17-04:00            Desktop       4  review              0
# 2023-07-02T11:55:51-04:00            Desktop       4  review              2
#
#                                                                     title  \
# published_date
# 2023-12-12T00:38:26-05:00                              Harvard University
# 2023-12-10T08:21:35-05:00                              Walk around campus
# 2023-11-07T21:20:21-05:00                  Interesting Harvard University
# 2023-09-29T08:44:17-04:00  Interesting walk around campus grounds & river
# 2023-07-02T11:55:51-04:00                       Beautiful historic campus
#
#                                                                         text
# published_date
# 2023-12-12T00:38:26-05:00  Harvard University was founded in 1636 and is ...
# 2023-12-10T08:21:35-05:00  We did a walk around most of the Harvard Campu...
# 2023-11-07T21:20:21-05:00  We had a walk through the university grounds w...
# 2023-09-29T08:44:17-04:00  Very interesting to wander around the grounds ...
# 2023-07-02T11:55:51-04:00  The beauty, charm, and architecture of so many...

# %% [markdown]
# ## Ejercicio 6
#
# Crea una variable `df` que contenga las columnas `published_platform`, `rating`, `type` y `helpful_votes` de los registros con las etiquetas de índice `0`, `1`, `10` y `100`. En otras palabras, genera el siguiente DataFrame:

# %%
df = harvard_reviews.iloc[[0,1,10,100]][['published_platform', 'rating', 'type', 'helpful_votes']]
df
# Out:
#                           published_platform  rating    type  helpful_votes
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review              0
# 2023-12-12T00:38:26-05:00            Desktop       4  review              0
# 2023-05-24T11:38:11-04:00             Mobile       4  review              0
# 2019-09-15T18:42:44-04:00             Mobile       3  review              2

# %% [markdown]
# ## Ejercicio 7
#
# Crea una variable `df` que contenga las columnas `title` y `text` de los 100 primeros registros.

# %%
df = harvard_reviews.iloc[:100][['title', 'text']]
df
# Out:
#                                                                        title  \
# published_date
# 2023-12-28T08:02:14-05:00                 Best classes and good environment
# 2023-12-12T00:38:26-05:00                                 Harvard University
# 2023-12-10T08:21:35-05:00                                 Walk around campus
# 2023-11-07T21:20:21-05:00                     Interesting Harvard University
# 2023-10-02T17:40:42-04:00  Lovely university campus has many historic and...
# ...                                                                      ...
# 2019-09-29T12:23:04-04:00                               So historic, just go
# 2019-09-28T03:45:25-04:00                     A most prestigious university
# 2019-09-26T13:22:13-04:00                                      Great History
# 2019-09-25T14:40:59-04:00                                Gorgeous Campus!!!
# 2019-09-25T08:07:04-04:00        Harvard University walking tour by students
#
#                                                                         text
# published_date
# 2023-12-28T08:02:14-05:00  Good thanks for everything good work group 👍 h...
# 2023-12-12T00:38:26-05:00  Harvard University was founded in 1636 and is ...
# 2023-12-10T08:21:35-05:00  We did a walk around most of the Harvard Campu...
# 2023-11-07T21:20:21-05:00  We had a walk through the university grounds w...
# 2023-10-02T17:40:42-04:00  Finally made it to Harvard!!  This iconic univ...
# ...                                                                      ...
# 2019-09-29T12:23:04-04:00  If you’re touring in Boston, why wouldn’t you ...
# 2019-09-28T03:45:25-04:00  There's a river between a Harvard undergraduat...
# 2019-09-26T13:22:13-04:00  We had a great tour of the university and the ...
# 2019-09-25T14:40:59-04:00  Harvard is gorgeous and while we were visiting...
# 2019-09-25T08:07:04-04:00  Xiadi our tour guide was very entertaining but...
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Ejercicio 8
#
# Crea un DataFrame llamado `harvard_rating` que contenga los registros donde los valores de la columna `rating` sean mayor que 3.

# %%
harvard_rating = harvard_reviews[harvard_reviews.rating > 3]
harvard_rating
# Out:
#                           published_platform  rating    type  helpful_votes  \
# published_date
# 2023-12-28T08:02:14-05:00             Mobile       5  review              0
# 2023-12-12T00:38:26-05:00            Desktop       4  review              0
# 2023-11-07T21:20:21-05:00            Desktop       4  review              0
# 2023-10-02T17:40:42-04:00            Desktop       5  review              0
# 2023-09-29T08:44:17-04:00            Desktop       4  review              0
# ...                                      ...     ...     ...            ...
# 2011-03-27T05:58:59-04:00            Desktop       4  review              1
# 2010-12-27T03:28:05-05:00            Desktop       5  review              0
# 2010-08-23T00:06:41-04:00            Desktop       5  review              0
# 2010-06-03T07:37:36-04:00            Desktop       5  review              2
# 2009-09-27T16:39:18-04:00            Desktop       5  review              1
#
#                                                                        title  \
# published_date
# 2023-12-28T08:02:14-05:00                 Best classes and good environment
# 2023-12-12T00:38:26-05:00                                 Harvard University
# 2023-11-07T21:20:21-05:00                     Interesting Harvard University
# 2023-10-02T17:40:42-04:00  Lovely university campus has many historic and...
# 2023-09-29T08:44:17-04:00     Interesting walk around campus grounds & river
# ...                                                                      ...
# 2011-03-27T05:58:59-04:00          Ganz gemütlich über den Campus schlendern
# 2010-12-27T03:28:05-05:00         beeindruckender Campus - alles first class
# 2010-08-23T00:06:41-04:00                              bellissima università
# 2010-06-03T07:37:36-04:00  Tolle Universität, definitiv einen Abstecher wert
# 2009-09-27T16:39:18-04:00                                            一度は行くべき
#
#                                                                         text
# published_date
# 2023-12-28T08:02:14-05:00  Good thanks for everything good work group 👍 h...
# 2023-12-12T00:38:26-05:00  Harvard University was founded in 1636 and is ...
# 2023-11-07T21:20:21-05:00  We had a walk through the university grounds w...
# 2023-10-02T17:40:42-04:00  Finally made it to Harvard!!  This iconic univ...
# 2023-09-29T08:44:17-04:00  Very interesting to wander around the grounds ...
# ...                                                                      ...
# 2011-03-27T05:58:59-04:00  Wenn man in Boston ist, sollte man auf jeden F...
# 2010-12-27T03:28:05-05:00  habe eine Tour durch über 10 Campusse der best...
# 2010-08-23T00:06:41-04:00  da vedere questa città, studio sede di una del...
# 2010-06-03T07:37:36-04:00  Hallo,\nich habe ein Jahr an der Harvard Law S...
# 2009-09-27T16:39:18-04:00  とても歴史のある素敵な建物です。ハーバードスクエアーの駅の近くから無料のツアー（英語）をハー...
#
# [2860 rows x 6 columns]

# %% [markdown]
# ## Ejercicio 9
#
# Crea un DataFrame llamado `harvard_mobile` que contenga los registros donde los valores de la columna `rating` sean mayor que 3 y además las reviews se hayan hecho por el móvil.
#
# Pista: Fíjate en la columna `published_platform`

# %%
harvard_mobile = harvard_reviews[(harvard_reviews.rating > 3) & (harvard_reviews.published_platform == 'mobile')]
harvard_mobile
# Out:
# Empty DataFrame
# Columns: [published_platform, rating, type, helpful_votes, title, text]
# Index: []

# %% [markdown]
# ## Ejercicio 10
#
# Añade una nueva columna al dataframe de `reviews` llamada `rating_europe` en la cuál se debe almacenar los valores de la columna `rating` multiplicados por 2.

# %%
rating_europe = harvard_reviews.rating * 2
rating_europe
# Out:
# published_date
# 2023-12-28T08:02:14-05:00    10
# 2023-12-12T00:38:26-05:00     8
# 2023-12-10T08:21:35-05:00     6
# 2023-11-07T21:20:21-05:00     8
# 2023-10-02T17:40:42-04:00    10
#                              ..
# 2010-10-29T05:47:57-04:00     6
# 2010-08-23T06:08:51-04:00     6
# 2010-08-23T00:06:41-04:00    10
# 2010-06-03T07:37:36-04:00    10
# 2009-09-27T16:39:18-04:00    10
# Name: rating, Length: 3184, dtype: int64

# %% [markdown]
# **Autoevaluación:**. En una escala del 6 al 10, donde 6 es el más bajo nivel de desempeño y 10 el más alto nivel, describa la calificación que se colocarían en el tema 1.

# %% [markdown]
# 10
# La verdad es que el profe explica muy bien los temas, sabe de que se trata y aparte las practicas que nos pone son muy practicas, Comprendi todo lo que nos enseño y llego a explicar
